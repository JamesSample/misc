# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Identifying limed catchments
#
# Atle has provided two Excel files:
#
#  1. A list of 1005 lakes proposed for a new national scale monitoring programme, and <br><br>
#
#  2. A list of 2957 lakes that have been historically limed (originally provided by Kari).
#
# This notebook links these two datasets based on lake IDs from NVE to see which of the sites in the new programme may have been limed in the past.
#
# ## 1. Read data
#
# The file containing data for the new programme has a few incomplete lines right at the end. I've removed these manually and copied the data to a new Excel file, along with the data from Kari.

# %%
# Read liming data
xl_path = r'../data/data_tidied.xlsx'
lim_df = pd.read_excel(xl_path, sheet_name='Limed_Catchments')
lim_df.head()
# Out:
#               Navn NVE-nr        UTM E32       UTM N32  Hoh (m)  \
# 0  "Øvre" Damtjørn  80270  519698.464062  6.661278e+06      0.0
# 1  "Øvre" Damtjørn  80270  519698.464062  6.661278e+06      0.0
# 2  "Øvre" Damtjørn  80270  519698.464062  6.661278e+06      0.0
# 3  "Øvre" Damtjørn  80270  519698.464062  6.661278e+06      0.0
# 4   (S)M, Ertevann   3380  638671.642401  6.597786e+06    239.0
#
#           Prøve fra år  "Ukalket" Ca (mg/l) TOC (mg/L)    Høyde Kalk  ...   \
# 0  2003-10-17 00:00:00             2.742715    11.6835  Lavland  1-4  ...
# 1  2006-09-06 00:00:00             1.222431        8.1  Lavland  1-4  ...
# 2  2007-05-28 00:00:00             0.801630        5.7  Lavland   <1  ...
# 3  2007-09-23 00:00:00             1.543639         11  Lavland  1-4  ...
# 4  2011-11-06 00:00:00             1.284453       17.2     Skog  1-4  ...
#
#   "Ukalket" Ca (mg/l).1  TOC (mg/L).1  Kalk.1 Humus.1 G/M ANC (uekv/l).1  \
# 0                   NaN           NaN     1-4      >5               30.0
# 1                   NaN           NaN     1-4      >5               30.0
# 2                   NaN           NaN  0.75-1      >5               30.0
# 3                   NaN           NaN     1-4      >5               30.0
# 4                   NaN           NaN     1-4      >5               30.0
#
#   "Ukalket" ANC (uekv/l) rapport  Ny "Ukalket" ANC (uekv/l) 2014  Usikkerhet  \
# 0                     164.577793                             NaN          40
# 1                      61.859097                             NaN          40
# 2                      44.701154                             NaN          40
# 3                      98.684502                             NaN          40
# 4                      83.570362                             NaN          25
#
#    Rapport  2014
# 0        S     S
# 1        U     U
# 2        U     U
# 3        S     S
# 4       U*     S
#
# [5 rows x 22 columns]

# %%
# Read new programme data
new_df = pd.read_excel(xl_path, sheet_name='New_Project')
new_df.head()
# Out:
#    Station ID Station Code  Station name Lake/River name  Kommune Nr  \
# 0        2999      101-4-1      Femsjøen        Femsjøen         101
# 1           9      101-2-7     Hokksjøen       Hokksjøen         101
# 2        2998      101-2-2  Steinsvatnet    Steinsvatnet         101
# 3        3000      105-3-6      Isesjøen        Isesjøen         105
# 4        3001     105-3-10    Tunevatnet      Tunevatnet         105
#
#              Kommune  Fylke Nr    Fylke  NVE Vatn nr     UTM North  \
# 0     Halden kommune         1  Østfold        316.0  6.559050e+06
# 1     Halden kommune         1  Østfold       3608.0  6.543369e+06
# 2     Halden kommune         1  Østfold       3562.0  6.554004e+06
# 3  Sarpsborg kommune         1  Østfold        133.0  6.572400e+06
# 4  Sarpsborg kommune         1  Østfold       3451.0  6.576676e+06
#
#         UTM East  UTM Zone  Lake Area  Altitude
# 0  642460.000000        32  10.640000        79
# 1  647241.906048        32   0.133879       148
# 2  652477.000000        32   0.210000       178
# 3  626400.000000        32   6.200000        38
# 4  619486.000000        32   2.250000        40

# %% [markdown]
# ## 2. Data checking

# %%
# Are the IDs in the limed dataset unique?
print 'Is unique?:       ', lim_df['NVE-nr'].is_unique
print 'Number unique:    ', len(lim_df['NVE-nr'].unique())
print 'Number without ID:', len(lim_df[lim_df['NVE-nr'].isnull()])
# Out:
# Is unique?:        False
# Number unique:     1565
# Number without ID: 0

# %% [markdown]
# So, there are many duplicated IDs in the limed dataset, but all rows have an ID. Looking down the e-mail chain from Atle, this is expected: Kari says the data sometimes includes single samples, so the same lake can appear on multiple lines. Based on the above, there are actually **1565 unique lakes in the limed dataset**.
#
# What about the new dataset?

# %%
# Are the IDs in the new dataset unique?
print 'Is unique?:       ', new_df['NVE Vatn nr'].is_unique
print 'Number unique:    ', len(new_df['NVE Vatn nr'].unique())
print 'Number without ID:', len(new_df[new_df['NVE Vatn nr'].isnull()])
# Out:
# Is unique?:        False
# Number unique:     1004
# Number without ID: 2

# %%
# Identify lakes with no ID
new_df[new_df['NVE Vatn nr'].isnull()]
# Out:
#      Station ID Station Code Station name Lake/River name  Kommune Nr  \
# 271       15705       830-26       Måvatn             NaN         830
# 305       15712       904-12   Snøløsvatn             NaN         904
#
#               Kommune  Fylke Nr       Fylke  NVE Vatn nr  UTM North  UTM East  \
# 271  Nissedal kommune         8    Telemark          NaN  6563000.0  478400.0
# 305  Grimstad kommune         9  Aust-Agder          NaN  6481832.0  468564.0
#
#      UTM Zone  Lake Area  Altitude
# 271        32       0.63       665
# 305        32       1.24       109

# %% [markdown]
# Two lakes in the new dataset are missing IDs. Can these be found in the limed dataset?

# %%
# Search limed data for Måvatn
lim_df[lim_df['Navn'].str.contains(u'Måvatn', na=False)]
# Out:
#                Navn NVE-nr        UTM E32       UTM N32  Hoh (m)  \
# 1417         Måvatn   8146  505672.432872  6.531369e+06    142.0
# 1418  Måvatn, store  13527  492168.776802  6.599101e+06    791.0
# 1419  Måvatn, vesle  13542  492953.501412  6.598952e+06    797.0
#
#              Prøve fra år  "Ukalket" Ca (mg/l) TOC (mg/L)    Høyde Kalk  ...   \
# 1417  2011-10-04 00:00:00             1.036021       10.5  Lavland  1-4  ...
# 1418  2011-10-16 00:00:00             0.654453        7.4     Skog   <1  ...
# 1419  2011-10-16 00:00:00             0.775113        8.3     Skog   <1  ...
#
#      "Ukalket" Ca (mg/l).1  TOC (mg/L).1    Kalk.1 Humus.1 G/M ANC (uekv/l).1  \
# 1417                   NaN           NaN       1-4      >5               30.0
# 1418                   NaN           NaN  0.5-0.75      >5               20.0
# 1419                   NaN           NaN  0.75-1.0      >5               30.0
#
#      "Ukalket" ANC (uekv/l) rapport  Ny "Ukalket" ANC (uekv/l) 2014  \
# 1417                      52.127344                             NaN
# 1418                      37.412865                             NaN
# 1419                      45.807358                             NaN
#
#       Usikkerhet  Rapport  2014
# 1417          30        U     U
# 1418          30        U     U
# 1419          30        U     U
#
# [3 rows x 22 columns]

# %% [markdown]
# There are 3 different Måvatns in the limed dataset, but none match the co-ordinates (or elevation) of the Måvatn in the new project. **Ask Atle to check whether Måvatn in the new project is one of the three above**.

# %%
# Search limed data for Snøløsvatn
lim_df[lim_df['Navn'].str.contains(u'Snøløsvatn', na=False)]
# Out:
# Empty DataFrame
# Columns: [Navn, NVE-nr, UTM E32, UTM N32, Hoh (m), Prøve fra år, "Ukalket" Ca (mg/l), TOC (mg/L), Høyde, Kalk, Humus, G/M ANC (uekv/l), "Ukalket" Ca (mg/l).1, TOC (mg/L).1, Kalk.1, Humus.1, G/M ANC (uekv/l).1, "Ukalket" ANC (uekv/l) rapport, Ny "Ukalket" ANC (uekv/l) 2014, Usikkerhet, Rapport, 2014]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# I can't find anything in the limed data to match 'Snøløsvatn'. For now, I will therefore ignore these two sites (Måvatn and Snøløsvatn).

# %%
# Drop rows without IDs from new dataset
new_df.dropna(axis=0, subset=['NVE Vatn nr',], inplace=True)
print 'Number of sites in new project with IDs:', len(new_df)
# Out:
# Number of sites in new project with IDs: 1003

# %%
# Convert NVE ID cols to str for safe matching
lim_df['NVE-nr'] = lim_df['NVE-nr'].astype(str)
new_df['NVE Vatn nr'] = new_df['NVE Vatn nr'].astype(int).astype(str)

# %% [markdown]
# ## 3. Identify limed catchments

# %%
# Get list of unique IDs for limed catchments
lim_uni = lim_df['NVE-nr'].unique()

# List lakes in 'new_df' that appear in 'lim_df'
union_df = new_df[new_df['NVE Vatn nr'].isin(lim_uni)]

# Save to CSV
union_df.to_csv(r'../Data/limed_sites_in_new_project.csv', encoding='utf-8')

# Print results
print ('There are %s sites in the new project '
       'that appear listed in the limed dataset:' % len(union_df))
union_df
# Out:
# There are 8 sites in the new project that appear listed in the limed dataset:
#      Station ID Station Code     Station name  Lake/River name  Kommune Nr  \
# 11         3008    128-2-111     Store Hosten     Store Hosten         128
# 32         3029     402-2-33       Fjellsjøen       Fjellsjøen         402
# 58         3052     428-2-24  Fiskebekktjørna  Fiskebekktjørna         428
# 159        3138     604-2-18      Tverrvatnet      Tverrvatnet         604
# 189        3168     621-1-27         Flåvatna         Flåvatna         621
# 193        3172     623-2-16      Damheggesjø      Damheggesjø         623
# 240       17942      817-606       Kleppsvatn              NaN         817
# 641        3574     1432-1-7       Nordvatnet       Nordvatnet        1432
#
#                  Kommune  Fylke Nr             Fylke NVE Vatn nr  UTM North  \
# 11     Rakkestad kommune         1           Østfold        3415  6592256.0
# 32   Kongsvinger kommune         4           Hedmark        4112  6681939.0
# 58        Trysil kommune         4           Hedmark       33453  6825188.0
# 159    Kongsberg kommune         6          Buskerud        6384  6593783.0
# 189       Sigdal kommune         6          Buskerud       18142  6673699.0
# 193        Modum kommune         6          Buskerud        5310  6645867.0
# 240    Drangedal kommune         8          Telemark        1245  6560359.0
# 641        Førde kommune        14  Sogn og Fjordane       28322  6829875.0
#
#      UTM East  UTM Zone  Lake Area  Altitude
# 11   644363.0        32       0.20       190
# 32   348777.0        33       0.59       384
# 58   650148.0        32       0.28       815
# 159  535801.0        32       0.14       529
# 189  510145.0        32       0.07       854
# 193  558939.0        32       0.17       588
# 240  482226.0        32       1.25       542
# 641  347236.0        32       0.07       893

# %% [markdown]
# ## 4. Summary
#
#  * There are 2 sites in new project (Måvatn and Snøløsvatn) without NVE IDs <br><br>
#
#  * Of these two, one (Måvatn) *might* be listed in the limed dataset, but there is no exact match. Perhaps Atle can check? For now, I have simply ignored these two sites <br><br>
#
#  * Of the remaining 1003 sites in the new project, 8 are listed in the limed dataset
